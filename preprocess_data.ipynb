# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import matplotlib.pyplot as plt

# %%
WORKING_DIRECTORY = '/content/drive/MyDrive/Colab\ Notebooks/diploma/'

# %%
 # Создаём SparkSession
spark = SparkSession.builder \
    .appName("PetCo") \
    .getOrCreate()

# %% [markdown]
# # Сначала подготовим датасет с последовательностями покупок

# %%
# Read dataset with beh logs
data_logs = spark.read.parquet(WORKING_DIRECTORY+'data/needed_beh_logs')

# %%
data_logs.show()
# Out:
# +----------------+--------------------+-----+--------------------+--------------------+--------------------+-----------------+-------------+--------------------+--------------------+-----------+--------------------+------------+--------------------+--------------------+--------------------+-------+
# |customer_user_id|              ac_key|ac_id|             user_id|          session_id|           timestamp|         raw_term|  filter_name|        filter_value|              action|customer_id|           item_name|variation_id|      variation_name|               items|            items_v2|revenue|
# +----------------+--------------------+-----+--------------------+--------------------+--------------------+-----------------+-------------+--------------------+--------------------+-----------+--------------------+------------+--------------------+--------------------+--------------------+-------+
# |       435675978|key_afiSr5Y4gCaaSW5X| 2560|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:16:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{aquariums-40-to...|[{aquariums-40-to...|   NULL|
# |       435675978|key_afiSr5Y4gCaaSW5X| 2546|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:16:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{Purina Pro Plan...|[{Purina Pro Plan...|   NULL|
# |       435675978|key_afiSr5Y4gCaaSW5X| 1947|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:16:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{5184324, 612301...|[{5184324, 612301...|   NULL|
# |       435675978|key_afiSr5Y4gCaaSW5X| NULL|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:16:...|nulo cat dry food|         NULL|                NULL|              search|       NULL|                NULL|        NULL|                NULL|                NULL|                NULL|   NULL|
# |       435675978|key_afiSr5Y4gCaaSW5X| 1947|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:18:...|nulo cat dry food|         NULL|                NULL|       click_through|    5184322|Nulo MedalSeries ...|  1864389465|Nulo MedalSeries ...|                NULL|                NULL|   NULL|
# |       435675978|key_afiSr5Y4gCaaSW5X| 1947|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:18:...|nulo cat dry food|         NULL|                NULL|       click_through|    5184324|Nulo MedalSeries ...|  1864389454|Nulo MedalSeries ...|                NULL|                NULL|   NULL|
# |       435675978|key_afiSr5Y4gCaaSW5X| 1947|e5fbf045-94fa-498...|e5fbf045-94fa-498...|2024-11-29 10:18:...|             NULL|         NULL|                NULL|    item_detail_load|    5184324|Nulo MedalSeries ...|  1864389454|Nulo MedalSeries ...|                NULL|                NULL|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|             NULL|     group_id|dog-poop-bags-and...|  browse_result_load|       NULL|                NULL|        NULL|                NULL|[{5012934, 366899...|[{5012934, 366899...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 2560|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{aquariums-40-to...|[{aquariums-40-to...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 2546|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{Purina Pro Plan...|[{Purina Pro Plan...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{5109955, 366900...|[{5109955, 366900...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1948|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|             zest|         NULL|                NULL|              select| zesty paws|          zesty paws|        NULL|                NULL|                NULL|                NULL|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| NULL|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|       zesty paws|         NULL|                NULL|              search|       NULL|                NULL|        NULL|                NULL|                NULL|                NULL|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:20:...|             NULL|Primary Brand|          Zesty Paws|  browse_result_load|       NULL|                NULL|        NULL|                NULL|[{5190824, 612302...|[{5190824, 612302...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:21:...|             NULL|Primary Brand|          Zesty Paws|  browse_result_load|       NULL|                NULL|        NULL|                NULL|[{5190824, 612302...|[{5190824, 612302...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 2560|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:29:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{aquariums-40-to...|[{aquariums-40-to...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 2546|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:29:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{Purina Pro Plan...|[{Purina Pro Plan...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:29:...|             NULL|         NULL|                NULL|recommendation_re...|       NULL|                NULL|        NULL|                NULL|[{5109955, 366900...|[{5109955, 366900...|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| NULL|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:29:...|       native pet|         NULL|                NULL|              search|       NULL|                NULL|        NULL|                NULL|                NULL|                NULL|   NULL|
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:29:...|             NULL|Primary Brand|          Native Pet|  browse_result_load|       NULL|                NULL|        NULL|                NULL|[{5196112, 612302...|[{5196112, 612302...|   NULL|
# +----------------+--------------------+-----+--------------------+--------------------+--------------------+-----------------+-------------+--------------------+--------------------+-----------+--------------------+------------+--------------------+--------------------+--------------------+-------+
# only showing top 20 rows

# %%
data_logs.printSchema()  # Структура данных
# Out:
# root
#  |-- customer_user_id: string (nullable = true)
#  |-- ac_key: string (nullable = true)
#  |-- ac_id: long (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- raw_term: string (nullable = true)
#  |-- filter_name: string (nullable = true)
#  |-- filter_value: string (nullable = true)
#  |-- action: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- item_name: string (nullable = true)
#  |-- variation_id: long (nullable = true)
#  |-- variation_name: string (nullable = true)
#  |-- items: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- customer_id: string (nullable = true)
#  |    |    |-- item_id: long (nullable = true)
#  |    |    |-- item_name: string (nullable = true)
#  |    |    |-- price: double (nullable = true)
#  |-- items_v2: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- customer_id: string (nullable = true)
#  |    |    |-- item_id: long (nullable = true)
#  |    |    |-- item_name: string (nullable = true)
#  |    |    |-- price: double (nullable = true)
#  |    |    |-- variation_customer_id: string (nullable = true)
#  |    |    |-- variation_id: long (nullable = true)
#  |    |    |-- variation_name: string (nullable = true)
#  |    |    |-- count: long (nullable = true)
#  |-- revenue: double (nullable = true)

# %%
data_purchases = data_logs.filter(data_logs.action == 'purchase')
print(f'Number of group purchases: {data_purchases.count()}')
# Out:
# Number of group purchases: 98248

# %%
data_purchases.show()
# Out:
# +----------------+--------------------+-----+--------------------+--------------------+--------------------+--------+-----------+------------+--------+-----------+---------+------------+--------------+--------------------+--------------------+-------+
# |customer_user_id|              ac_key|ac_id|             user_id|          session_id|           timestamp|raw_term|filter_name|filter_value|  action|customer_id|item_name|variation_id|variation_name|               items|            items_v2|revenue|
# +----------------+--------------------+-----+--------------------+--------------------+--------------------+--------+-----------+------------+--------+-----------+---------+------------+--------------+--------------------+--------------------+-------+
# |       635619080|key_afiSr5Y4gCaaSW5X| 1947|6521ca44-0aed-409...|6521ca44-0aed-409...|2024-11-29 01:34:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5190834, 612302...|[{5190834, 612302...|  57.16|
# |       636184329|key_afiSr5Y4gCaaSW5X| 1947|6943aa68-382f-4e7...|6943aa68-382f-4e7...|2024-11-29 19:42:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5028719, 366899...|[{5028719, 366899...| 165.08|
# |        25837854|key_afiSr5Y4gCaaSW5X| 1947|506d4b30-7b36-4a5...|506d4b30-7b36-4a5...|2024-11-29 23:10:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5081330, 366900...|[{5081330, 366900...|  58.92|
# |       174318756|key_afiSr5Y4gCaaSW5X| 1947|660c2d2c-1406-471...|660c2d2c-1406-471...|2024-11-29 23:21:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5146187, 612301...|[{5146187, 612301...| 192.26|
# |       507282061|key_afiSr5Y4gCaaSW5X| 1947|ddf3158e-2777-463...|ddf3158e-2777-463...|2024-11-29 22:27:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5106650, 366900...|[{5106650, 366900...|  44.99|
# |       492387644|key_afiSr5Y4gCaaSW5X| 1947|1dc16681-6a92-4af...|1dc16681-6a92-4af...|2024-11-29 04:19:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5083092, 366900...|[{5083092, 366900...|  34.98|
# |       452488104|key_afiSr5Y4gCaaSW5X| 1947|4573b15f-f461-47e...|4573b15f-f461-47e...|2024-11-29 13:07:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5052767, 366899...|[{5052767, 366899...| 158.01|
# |       131362932|key_afiSr5Y4gCaaSW5X| 1947|2af1517e-2b71-479...|2af1517e-2b71-479...|2024-11-29 22:05:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5158160, 612301...|[{5158160, 612301...|  42.99|
# |       570785604|key_afiSr5Y4gCaaSW5X| 1947|07fcd752-b749-406...|07fcd752-b749-406...|2024-11-29 03:03:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5004132, 366899...|[{5004132, 366899...| 136.25|
# |       210090739|key_afiSr5Y4gCaaSW5X| 1947|0016461e-4a2e-462...|0016461e-4a2e-462...|2024-11-29 21:54:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5051710, 582061...|[{5051710, 582061...| 133.88|
# |       578050917|key_afiSr5Y4gCaaSW5X| 1947|98845d49-727d-4ed...|98845d49-727d-4ed...|2024-11-29 00:09:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5023795, 366899...|[{5023795, 366899...|  78.58|
# |        39592718|key_afiSr5Y4gCaaSW5X| 1947|dbe5b8b2-b01d-484...|dbe5b8b2-b01d-484...|2024-11-29 01:52:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5107322, 366900...|[{5107322, 366900...|  146.7|
# |       137678677|key_afiSr5Y4gCaaSW5X| 1947|53d6af3b-aa89-4ae...|53d6af3b-aa89-4ae...|2024-11-29 21:53:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5053235, 366899...|[{5053235, 366899...|  81.99|
# |       508035727|key_afiSr5Y4gCaaSW5X| 1947|c9c018e4-1335-4b7...|c9c018e4-1335-4b7...|2024-11-29 16:40:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5190091, 612302...|[{5190091, 612302...| 224.84|
# |       184995957|key_afiSr5Y4gCaaSW5X| 1947|b3aa94f9-3ee5-44e...|b3aa94f9-3ee5-44e...|2024-11-29 13:31:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5022225, 366899...|[{5022225, 366899...|  49.98|
# |       622205925|key_afiSr5Y4gCaaSW5X| 1947|acb5ea9b-700b-485...|acb5ea9b-700b-485...|2024-11-29 18:57:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5069364, 366900...|[{5069364, 366900...| 101.56|
# |       209208815|key_afiSr5Y4gCaaSW5X| 1947|30c57f83-c297-484...|30c57f83-c297-484...|2024-11-29 09:19:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{4364, 366898826...|[{4364, 366898826...| 153.99|
# |       304915207|key_afiSr5Y4gCaaSW5X| 1947|9b271219-0d82-48a...|9b271219-0d82-48a...|2024-11-29 19:01:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5234361, 637339...|[{5234361, 637339...|  85.52|
# |       544932044|key_afiSr5Y4gCaaSW5X| 1947|c1be5ce9-6f4d-472...|c1be5ce9-6f4d-472...|2024-11-29 22:08:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5234498, 638098...|[{5234498, 638098...| 115.08|
# |       544932044|key_afiSr5Y4gCaaSW5X| 1947|c1be5ce9-6f4d-472...|c1be5ce9-6f4d-472...|2024-11-29 22:28:...|    NULL|       NULL|        NULL|purchase|       NULL|     NULL|        NULL|          NULL|[{5107210, 366900...|[{5107210, 366900...|  71.98|
# +----------------+--------------------+-----+--------------------+--------------------+--------------------+--------+-----------+------------+--------+-----------+---------+------------+--------------+--------------------+--------------------+-------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import explode, col, lit

# Разворачиваем массив items
data_purchases_transformed = data_purchases.select(
    col("customer_user_id"),
    explode("items").alias("item"),  # Разворачиваем массив товаров
    lit(1).alias("purchase"),  # Добавляем столбец с 1
    col("timestamp")
).select(
    col("customer_user_id"),
    col("item.customer_id").alias("customer_id"),  # Извлекаем customer_id из структуры
    col("purchase"),
    col("timestamp")
)

data_purchases_transformed.show()
# Out:
# +----------------+-----------+--------+--------------------+
# |customer_user_id|customer_id|purchase|           timestamp|
# +----------------+-----------+--------+--------------------+
# |       635619080|    5190834|       1|2024-11-29 01:34:...|
# |       635619080|    5025044|       1|2024-11-29 01:34:...|
# |       635619080|    5025045|       1|2024-11-29 01:34:...|
# |       636184329|    5028719|       1|2024-11-29 19:42:...|
# |       636184329|    5025045|       1|2024-11-29 19:42:...|
# |       636184329|    5095824|       1|2024-11-29 19:42:...|
# |       636184329|    5025044|       1|2024-11-29 19:42:...|
# |       636184329|    5001348|       1|2024-11-29 19:42:...|
# |       636184329|    5095826|       1|2024-11-29 19:42:...|
# |       636184329|    5077002|       1|2024-11-29 19:42:...|
# |       636184329|    5077002|       1|2024-11-29 19:42:...|
# |       636184329|    5077004|       1|2024-11-29 19:42:...|
# |        25837854|    5081330|       1|2024-11-29 23:10:...|
# |        25837854|       9082|       1|2024-11-29 23:10:...|
# |        25837854|    5108245|       1|2024-11-29 23:10:...|
# |        25837854|    5189562|       1|2024-11-29 23:10:...|
# |       174318756|    5146187|       1|2024-11-29 23:21:...|
# |       174318756|    5056848|       1|2024-11-29 23:21:...|
# |       174318756|    5056801|       1|2024-11-29 23:21:...|
# |       174318756|    5234321|       1|2024-11-29 23:21:...|
# +----------------+-----------+--------+--------------------+
# only showing top 20 rows

# %%
# Определяем путь для сохранения
output_path = '/content/drive/My Drive/Colab Notebooks/diploma/results/processed datasets/'

# Сохраняем DataFrame в файл Parquet
data_purchases_transformed.write.mode("overwrite").parquet(output_path)

print(f"Датасет сохранён по пути {output_path}.")
# Out:
# Датасет сохранён по пути /content/drive/My Drive/Colab Notebooks/diploma/results/processed datasets/.

# %%
# Переводим PySpark DataFrame в Pandas
pandas_data_purchases_transformed = data_purchases_transformed.toPandas()

# Указываем путь для сохранения CSV
output_csv_path = '/content/drive/My Drive/Colab Notebooks/diploma/results/processed_data/purchases.csv'

# Сохраняем Pandas DataFrame в CSV
pandas_data_purchases_transformed.to_csv(output_csv_path, index=False)

print(f"Датасет сохранён в формате CSV по пути {output_csv_path}.")
# Out:
# Датасет сохранён в формате CSV по пути /content/drive/My Drive/Colab Notebooks/diploma/results/processed_data/purchases.csv.

# %%
import pandas as pd
pd.read_csv('/content/drive/My Drive/Colab Notebooks/diploma/results/processed_data/purchases.csv')
# Out:
#         customer_user_id  customer_id  purchase                timestamp
# 0              635619080      5190834         1  2024-11-29 01:34:57.295
# 1              635619080      5025044         1  2024-11-29 01:34:57.295
# 2              635619080      5025045         1  2024-11-29 01:34:57.295
# 3              636184329      5028719         1  2024-11-29 19:42:45.191
# 4              636184329      5025045         1  2024-11-29 19:42:45.191
# ...                  ...          ...       ...                      ...
# 339486         555831271      5106697         1  2024-06-23 11:56:22.133
# 339487          76786633      5224513         1  2024-06-23 19:02:41.761
# 339488          76786633      5052535         1  2024-06-23 19:02:41.761
# 339489          76786633      5169632         1  2024-06-23 19:02:41.761
# 339490          76786633      5190246         1  2024-06-23 19:02:41.761
#
# [339491 rows x 4 columns]

# %%
# import os
# from google.colab import drive

# # Монтируем Google Drive
# drive.mount('/content/drive')

# # Проверяем, существует ли директория
# directory_path = '/content/drive/My Drive/Colab Notebooks/diploma/results/processed datasets/'
# if not os.path.exists(directory_path):
#     os.makedirs(directory_path)
#     print(f"Папка {directory_path} создана.")
# else:
#     print(f"Папка {directory_path} существует.")

# # Сохраняем DataFrame в Google Drive
# output_path = '/content/drive/My Drive/Colab Notebooks/diploma/results/processed datasets/processed_data.parquet'
# final_df.write.mode("overwrite").parquet(output_path)

# # Чтение файла Parquet
# df = spark.read.parquet(output_path)
# df.show(truncate=False)

# %% [markdown]
# # Теперь подготовим датасет с описанием товаров

# %%
# Read dataset with beh logs
data_items = spark.read.parquet(WORKING_DIRECTORY+'data/data_set_items')
data_items.show()
# Out:
# +----------+---------------+--------------------+-----+-----------+--------------------+--------------------+--------------+-------------+--------------------+------------+-------------------+-------------------+----------+--------------------+
# |        id|autocomplete_id|                name|score|customer_id|          name_lower|       metadata_json|computed_score|boost_or_bury|    ds_metadata_json|section_name|         created_at|         updated_at|       day|              ac_key|
# +----------+---------------+--------------------+-----+-----------+--------------------+--------------------+--------------+-------------+--------------------+------------+-------------------+-------------------+----------+--------------------+
# |3668992957|           1947|Kaytee Forti-Diet...|   -1|    5017277|kaytee forti-diet...|{"url": "/shop/en...|         68803|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:09:22|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668994348|           1947|Perfect Pet Scree...|   -1|    5023023|perfect pet scree...|{"url": "/shop/en...|         68236|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:19:00|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668994861|           1947|Tiki Cat Aloha Fr...|   -1|    5024527|tiki cat aloha fr...|{"url": "/shop/en...|         73428|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 01:50:00|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668992179|           1947|Exo Terra Mini Wi...|   -1|    5013114|exo terra mini wi...|{"url": "/shop/en...|         73095|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668987634|           1947|Coastal Pet Nylon...|   -1|     118386|coastal pet nylon...|{"url": "/shop/en...|         67749|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:01:05|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668991497|           1947|Fluval AquaClear ...|   -1|    5008476|fluval aquaclear ...|{"url": "/shop/en...|         70954|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 01:24:52|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668991923|           1947|Bond & Co Blue Fi...|   -1|    5010682|bond & co blue fi...|{"url": "/shop/en...|         67964|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668988099|           1947|PetAg Esbilac 2nd...|   -1|       6506|petag esbilac 2nd...|{"url": "/shop/en...|         81584|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 01:50:00|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668992723|           1947|Petlinks Roaming ...|   -1|    5016775|petlinks roaming ...|{"url": "/shop/en...|         67949|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668990715|           1947|Imagitarium Media...|   -1|    5004623|imagitarium media...|{"url": "/shop/en...|         72007|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 23:59:57|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668991435|           1947|Fluval AquaClear ...|   -1|    5008255|fluval aquaclear ...|{"url": "/shop/en...|         93712|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:09:22|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668989647|           1947|RockGarden Tufa R...|   -1|    5000760|rockgarden tufa r...|{"url": "/shop/en...|         68270|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668993609|           1947|Hill's Prescripti...|   -1|    5021015|hill's prescripti...|{"url": "/shop/en...|         77028|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:19:00|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668992914|           1947|Pets First Tampa ...|   -1|    5017735|pets first tampa ...|{"url": "/shop/en...|         67932|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 00:35:25|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668993753|           1947|Majestic Pet Vill...|   -1|    5021050|majestic pet vill...|{"url": "/shop/en...|         67961|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668991152|           1947|Blue Buffalo Blue...|   -1|    5001342|blue buffalo blue...|{"url": "/shop/en...|         70282|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668987365|           1947|Espree Natural Ki...|   -1|     103769|espree natural ki...|{"url": "/shop/en...|         72401|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 00:52:43|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668988831|           1947|Soulistic Origina...|   -1|    5003014|soulistic origina...|{"url": "/shop/en...|         84443|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:01:05|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668995383|           1947|Good Lovin' Hicko...|   -1|    5026292|good lovin' hicko...|{"url": "/shop/en...|         73907|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-26 02:19:00|2024-06-26|key_afiSr5Y4gCaaSW5X|
# |3668995707|           1947|Nylabone Teethe '...|   -1|    5027536|nylabone teethe '...|{"url": "/shop/en...|         68544|            0|{"weighted_keywor...|    Products|2022-05-16 14:44:33|2024-06-25 21:31:19|2024-06-26|key_afiSr5Y4gCaaSW5X|
# +----------+---------------+--------------------+-----+-----------+--------------------+--------------------+--------------+-------------+--------------------+------------+-------------------+-------------------+----------+--------------------+
# only showing top 20 rows

# %%
data_items.printSchema()  # Структура данных
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- autocomplete_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- score: integer (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- name_lower: string (nullable = true)
#  |-- metadata_json: string (nullable = true)
#  |-- computed_score: integer (nullable = true)
#  |-- boost_or_bury: integer (nullable = true)
#  |-- ds_metadata_json: string (nullable = true)
#  |-- section_name: string (nullable = true)
#  |-- created_at: timestamp (nullable = true)
#  |-- updated_at: timestamp (nullable = true)
#  |-- day: string (nullable = true)
#  |-- ac_key: string (nullable = true)

# %%
# Оставляем только столбцы id, customer_id, name, name_lower, metadata_json
data_items_filtered = data_items.select("id", "customer_id", "name", "name_lower", "metadata_json")

# Показываем результат
data_items_filtered.show(truncate=False)
# Out:
# +----------+-----------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |id        |customer_id|name                                                                                |name_lower                                                                          |metadata_json                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----------+-----------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |3668992957|5017277    |Kaytee Forti-Diet Pro Health Mouse, Rat Food                                        |kaytee forti-diet pro health mouse, rat food                                        |{"url": "/shop/en/petcostore/product/kaytee-fortidiet-prohealth-ratmouse-food-5-lbs", "facets": {"Line": ["Forti-Diet Pro Health"], "form": ["Powder or Pellets or Granules"], "Organic": ["No"], "Holistic": ["No"], "Pet Type": ["Rat"], "Food Form": ["Powder or Pellets or Granules"], "Lifestage": ["All Lifestages"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Kaytee"], "Customer Rating": [4.5395], "Killed Item flag": ["No"], "Primary Pet Type": ["Small Animal"], "Rx Food Indicator": ["No"], "Dietary Preference": ["With Grain"], "Personalized Item flag": ["No"], "PTC_OMNI_BRAND_SUB_BRND": ["Forti-Diet Pro Health"], "Limited Ingredients Diet": ["No"]}, "mfName": "Kaytee", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1226754-center-1", "itemurl": "/shop/en/petcostore/product/kaytee-fortidiet-prohealth-ratmouse-food-5-lbs", "itemname": "Kaytee Forti-Diet Pro Health Mouse, Rat Food", "group_ids": ["repeat-delivery-eligible-products", "rat-food", "small-animal-repeat-delivery-products", "same-day-delivery-small-pet-products", "small-animal-food", "buy-online-pick-up-in-store-small-animal-products"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1226754-center-1", "startDate": 26297760, "UPC_NUMBER": 71859000015, "deactivated": false, "AverageRating": 4.5395, "TotalReviewCount": 76, "parentCatEntryID": 865023, "PTC_OMNI_TAXONOMY": "Consumables|Food|Household Pet", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_RX_FOOD_IND": "No", "PTC_OMNI_LIVE_FOOD_FL": "No", "PTC_OMNI_BRAND_PRIMARY": "Kaytee", "parentCatEntryIDAsString": "865023", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                               |
# |3668994348|5023023    |Perfect Pet Screen Guard Pet Door in White                                          |perfect pet screen guard pet door in white                                          |{"url": "/shop/en/petcostore/product/ideal-pet-screen-guard", "facets": {"Material": ["Plastic"], "How to get it": ["One Time Delivery"], "Primary Brand": ["Perfect Pet"], "Primary Color": ["White"], "Customer Rating": [5.0], "Killed Item flag": ["No"], "Primary Pet Type": ["Cat,Dog"], "Personalized Item flag": ["No"]}, "mfName": "Perfect Pet", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2765752-center-1", "itemurl": "/shop/en/petcostore/product/ideal-pet-screen-guard", "itemname": "Perfect Pet Screen Guard Pet Door in White", "group_ids": ["cat-doors-and-flaps", "dog-patio-mount-doors"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2765752-center-1", "startDate": 27860825, "UPC_NUMBER": 30559100913, "deactivated": false, "AverageRating": 5.0, "TotalReviewCount": 1, "parentCatEntryID": 1272003, "PTC_OMNI_TAXONOMY": "Pet Containment|Gates, Fences & Doors", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_PROP_65_DESC": "WARNING: This product can expose you to chemicals, which are known to the state of California to cause cancer, birth defects or other reproductive harm. For more information, visit www.P65Warnings.ca.gov.", "PTC_OMNI_PROP_65_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Perfect Pet", "parentCatEntryIDAsString": "1272003", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |3668994861|5024527    |Tiki Cat Aloha Friends Tuna, Shrimp & Pumpkin Wet Cat Food                          |tiki cat aloha friends tuna, shrimp & pumpkin wet cat food                          |{"url": "/shop/en/petcostore/product/tiki-cat-aloha-friends-tuna-shrimp-and-pumpkin-wet-cat-food", "facets": {"Line": ["Aloha Friends"], "form": ["Chunky"], "Flavor": ["Fish"], "Organic": ["No"], "Holistic": ["Yes"], "Food Form": ["Wet"], "Lifestage": ["All Lifestages"], "How to get it": ["One Time Delivery"], "Primary Brand": ["Tiki Cat"], "Health Feature": ["Grain-Free"], "Primary Flavor": ["Tuna"], "Customer Rating": [4.5], "Killed Item flag": ["Yes"], "Primary Pet Type": ["Cat"], "Rx Food Indicator": ["No"], "Dietary Preference": ["Holistic", "Grain-Free"], "Personalized Item flag": ["No"], "PTC_OMNI_BRAND_SUB_BRND": ["Aloha Friends"], "Prescription Medication": ["No"], "Limited Ingredients Diet": ["No"]}, "mfName": "Tiki Cat", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2761778-center-1", "itemurl": "/shop/en/petcostore/product/tiki-cat-aloha-friends-tuna-shrimp-and-pumpkin-wet-cat-food", "itemname": "Tiki Cat Aloha Friends Tuna, Shrimp & Pumpkin Wet Cat Food", "group_ids": ["repeat-delivery-eligible-products", "fall-shop-food", "premium-cat-food", "bogo-cat-food-deals", "canned-cat-food"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2761778-center-1", "startDate": 27917545, "UPC_NUMBER": 693804400383, "deactivated": false, "AverageRating": 4.5, "TotalReviewCount": 18, "parentCatEntryID": 1462023, "PTC_OMNI_TAXONOMY": "Consumables|Food|Household Pet", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_RX_FOOD_IND": "No", "PTC_OMNI_LIVE_FOOD_FL": "No", "PTC_OMNI_PROP_65_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Tiki Cat", "PTC_OMNI_FLAVOR_PRIMARY": "Tuna", "parentCatEntryIDAsString": "1462023", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                     |
# |3668992179|5013114    |Exo Terra Mini Wide Terrarium, 12"x12"x12"                                          |exo terra mini wide terrarium, 12"x12"x12"                                          |{"url": "/shop/en/petcostore/product/exo-terra-mini-wide-terrarium-12x12x12", "facets": {"Pet": ["Reptile"], "Gallons": ["Up to 10 Gallons"], "Features": ["Personalized"], "Pet Type": ["Amphibian"], "How to get it": ["One Time Delivery"], "Primary Brand": ["Exo-Terra"], "Customer Rating": [4.35], "Killed Item flag": ["No"], "Primary Pet Type": ["Reptile"], "Personalized Item flag": ["Yes"]}, "mfName": "Exo-Terra", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/994154-center-3", "itemurl": "/shop/en/petcostore/product/exo-terra-mini-wide-terrarium-12x12x12", "itemname": "Exo Terra Mini Wide Terrarium, 12\"x12\"x12\"", "group_ids": ["snake-tanks-and-terrariums", "reptile-habitats-and-enclosures", "crested-gecko-cages-terrariums", "hermit-crab-tanks-terrariums", "frog-tanks-and-terrariums", "spider-terrariums"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/994154-center-3", "startDate": 26297760, "UPC_NUMBER": 15561226004, "deactivated": false, "AverageRating": 4.35, "TotalReviewCount": 60, "parentCatEntryID": 557052, "PTC_OMNI_TAXONOMY": "Pet Containment|Aquariums & Terrariums|Terrariums", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_PROP_65_DESC": "This product can expose you to chemicals including Styrene, which is known to the State of California to cause cancer. For more information go to www.P65Warnings.ca.gov", "PTC_OMNI_PROP_65_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Exo-Terra", "parentCatEntryIDAsString": "557052", "PTC_OMNI_PET_TYPE_PRIMARY": "Reptile", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "Yes", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                                                                                                                                                            |
# |3668987634|118386     |Coastal Pet Nylon Personalized Dog Leash in Light Blue, 5/8" Width                  |coastal pet nylon personalized dog leash in light blue, 5/8" width                  |{"url": "/shop/en/petcostore/product/coastal-pet-nylon-personalized-dog-leash-in-light-blue", "facets": {"Pet": ["Dog"], "Features": ["Personalized"], "How to get it": ["One Time Delivery"], "Primary Brand": ["Coastal Pet"], "Primary Color": ["Blue"], "Customer Rating": [5.0], "Killed Item flag": ["No"], "Primary Pet Type": ["Dog"], "Personalized Item flag": ["Yes"]}, "mfName": "Coastal Pet", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1472879-center-1", "itemurl": "/shop/en/petcostore/product/coastal-pet-nylon-personalized-dog-leash-in-light-blue", "itemname": "Coastal Pet Nylon Personalized Dog Leash in Light Blue, 5/8\" Width", "group_ids": ["dog-leashes", "personalized-leashes"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1472879-center-1", "startDate": 27917265, "UPC_NUMBER": 76484404078, "deactivated": false, "AverageRating": 5.0, "TotalReviewCount": 1, "parentCatEntryID": 20878, "PTC_OMNI_TAXONOMY": "Hardware|Connecting & Fastening", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Coastal Pet", "parentCatEntryIDAsString": "20878", "PTC_OMNI_PET_TYPE_PRIMARY": "Dog", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "Yes", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |3668991497|5008476    |Fluval AquaClear 30 Filter Insert Foam                                              |fluval aquaclear 30 filter insert foam                                              |{"url": "/shop/en/petcostore/product/aquaclear-30-filter-insert-foam", "facets": {"Pet": ["Fish"], "Line": ["AquaClear"], "Pet Type": ["Freshwater"], "Max Volume": ["30 GAL"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Fluval"], "Customer Rating": [4.875], "Killed Item flag": ["No"], "Primary Pet Type": ["Fish"], "Personalized Item flag": ["No"], "PTC_OMNI_BRAND_SUB_BRND": ["AquaClear"]}, "mfName": "Fluval", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/165441-center-1", "itemurl": "/shop/en/petcostore/product/aquaclear-30-filter-insert-foam", "itemname": "Fluval AquaClear 30 Filter Insert Foam", "group_ids": ["fish-repeat-delivery-products", "repeat-delivery-eligible-products", "fish-tank-filter-media", "same-day-delivery-fish-products", "saltwater-aquarium-filters-media", "aquatic-tank-equipment", "buy-online-pick-up-in-store-fish-products"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/165441-center-1", "startDate": 26297760, "UPC_NUMBER": 15561106054, "deactivated": false, "AverageRating": 4.875, "TotalReviewCount": 16, "parentCatEntryID": 295012, "PTC_OMNI_TAXONOMY": "Tools|Non-Powered Tools|Filtration Tools", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Fluval", "parentCatEntryIDAsString": "295012", "PTC_OMNI_PET_TYPE_PRIMARY": "Fish", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |3668991923|5010682    |Bond & Co Blue Fishbone Print Kitten Collar                                         |bond & co blue fishbone print kitten collar                                         |{"url": "/shop/en/petcostore/product/bond-and-co-blue-fishbone-print-kitten-collar", "facets": {"How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["Bond & Co"], "Primary Color": ["Blue"], "Customer Rating": [4.3846], "Killed Item flag": ["Yes"], "Primary Pet Type": ["Cat"], "Personalized Item flag": ["No"]}, "mfName": "Bond & Co", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2503381-center-1", "itemurl": "/shop/en/petcostore/product/bond-and-co-blue-fishbone-print-kitten-collar", "itemname": "Bond & Co Blue Fishbone Print Kitten Collar", "group_ids": ["standard-cat-collars", "same-day-delivery-cat-products", "cat-holiday-collars-leashes-harnesses", "buy-online-pick-up-in-store-cat-products"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2503381-center-1", "startDate": 26297760, "UPC_NUMBER": 800443201183, "deactivated": false, "AverageRating": 4.3846, "TotalReviewCount": 26, "parentCatEntryID": 427007, "PTC_OMNI_TAXONOMY": "Apparel|Collars|Standard Collars", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Bond & Co", "parentCatEntryIDAsString": "427007", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |3668988099|6506       |PetAg Esbilac 2nd Step Puppy Weaning Food                                           |petag esbilac 2nd step puppy weaning food                                           |{"url": "/shop/en/petcostore/product/petag-esbilac-2nd-step-puppy-weaning-food", "facets": {"Pet": ["Dog"], "Lifestage": ["Puppy"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery", "Repeat Delivery"], "Primary Brand": ["PetAg"], "Customer Rating": [4.505], "Killed Item flag": ["No"], "Primary Pet Type": ["Dog"], "Personalized Item flag": ["No"]}, "mfName": "PetAg", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/34568-center-1", "itemurl": "/shop/en/petcostore/product/petag-esbilac-2nd-step-puppy-weaning-food", "itemname": "PetAg Esbilac 2nd Step Puppy Weaning Food", "group_ids": ["same-day-delivery-dog-products", "dog-repeat-delivery-products", "repeat-delivery-eligible-products", "buy-online-pick-up-in-store-dog-products", "milk-replacers"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/34568-center-1", "startDate": 27917265, "UPC_NUMBER": 20279997016, "deactivated": false, "AverageRating": 4.505, "TotalReviewCount": 101, "parentCatEntryID": 27497, "PTC_OMNI_TAXONOMY": "Consumables|Vitamins & Supplements", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "PetAg", "parentCatEntryIDAsString": "27497", "PTC_OMNI_PET_TYPE_PRIMARY": "Dog", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |3668992723|5016775    |Petlinks Roaming Runner Mouse                                                       |petlinks roaming runner mouse                                                       |{"url": "/shop/en/petcostore/product/worldwise-roaming-runner-mouse", "facets": {"How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["Petlinks"], "Primary Color": ["Grey"], "Customer Rating": [2.5122], "Killed Item flag": ["Yes"], "Primary Pet Type": ["Cat"], "Personalized Item flag": ["No"]}, "mfName": "Petlinks", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2575975-center-2", "itemurl": "/shop/en/petcostore/product/worldwise-roaming-runner-mouse", "itemname": "Petlinks Roaming Runner Mouse", "group_ids": ["responsible-packaging-cat-supplies", "same-day-delivery-cat-products", "buy-online-pick-up-in-store-cat-products", "electronic-cat-toys", "mice-cat-toys"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2575975-center-2", "startDate": 25772160, "UPC_NUMBER": 786306495398, "deactivated": false, "AverageRating": 2.5122, "TotalReviewCount": 82, "parentCatEntryID": 719005, "PTC_OMNI_TAXONOMY": "Toys", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Petlinks", "parentCatEntryIDAsString": "719005", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |3668990715|5004623    |Imagitarium Media Mesh Filter Bag                                                   |imagitarium media mesh filter bag                                                   |{"url": "/shop/en/petcostore/product/imagitarium-media-mesh-filter-bag", "facets": {"Pet": ["Fish"], "Pet Type": ["Betta"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["Imagitarium"], "Customer Rating": [4.431], "Killed Item flag": ["Yes"], "Primary Pet Type": ["Fish"], "Personalized Item flag": ["No"]}, "mfName": "Imagitarium", "TopSold": 40025.0, "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2332130-center-1", "itemurl": "/shop/en/petcostore/product/imagitarium-media-mesh-filter-bag", "itemname": "Imagitarium Media Mesh Filter Bag", "group_ids": ["imagitarium-deals", "betta-filters-media", "repeat-delivery-eligible-products", "fish-tank-filter-media", "same-day-delivery-fish-products", "saltwater-aquarium-filters-media", "aquatic-tank-equipment", "buy-online-pick-up-in-store-fish-products"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2332130-center-1", "UPC_NUMBER": 800443970546, "deactivated": false, "AverageRating": 4.431, "TotalReviewCount": 58, "parentCatEntryID": 140507, "PTC_OMNI_TAXONOMY": "Tools|Non-Powered Tools|Filtration Tools", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Imagitarium", "parentCatEntryIDAsString": "140507", "PTC_OMNI_PET_TYPE_PRIMARY": "Fish", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# |3668991435|5008255    |Fluval AquaClear 20 Aquarium Power Filter                                           |fluval aquaclear 20 aquarium power filter                                           |{"url": "/shop/en/petcostore/product/aquaclear-20-aquarium-power-filter", "facets": {"Pet": ["Fish"], "Line": ["AquaClear"], "Pet Type": ["Freshwater"], "Max Volume": ["20 GAL"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["Fluval"], "Customer Rating": [4.3957], "Killed Item flag": ["No"], "Primary Pet Type": ["Fish"], "Personalized Item flag": ["No"], "PTC_OMNI_BRAND_SUB_BRND": ["AquaClear"], "Prescription Medication": ["No"]}, "mfName": "Fluval", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/172855-center-1", "itemurl": "/shop/en/petcostore/product/aquaclear-20-aquarium-power-filter", "itemname": "Fluval AquaClear 20 Aquarium Power Filter", "group_ids": ["same-day-delivery-fish-products", "fish-tank-filters", "saltwater-aquarium-filters-media", "fish-aquarium-equipment", "aquatic-tank-equipment", "buy-online-pick-up-in-store-fish-products"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/172855-center-1", "startDate": 26297760, "UPC_NUMBER": 15561105958, "deactivated": false, "AverageRating": 4.3957, "TotalReviewCount": 139, "parentCatEntryID": 291510, "PTC_OMNI_TAXONOMY": "Appliances|Filtration Appliances", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_PROP_65_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Fluval", "parentCatEntryIDAsString": "291510", "PTC_OMNI_PET_TYPE_PRIMARY": "Fish", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# |3668989647|5000760    |RockGarden Tufa Rock Aquarium Plant                                                 |rockgarden tufa rock aquarium plant                                                 |{"url": "/shop/en/petcostore/product/rockgarden-tufa-rock-aquarium-plant", "facets": {"Pet": ["Fish"], "Pet Type": ["Betta"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["RockGarden"], "Primary Color": ["Green"], "Customer Rating": [4.0625], "Killed Item flag": ["Yes"], "Primary Pet Type": ["Fish"], "Personalized Item flag": ["No"]}, "mfName": "RockGarden", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1254898-center-1", "itemurl": "/shop/en/petcostore/product/rockgarden-tufa-rock-aquarium-plant", "itemname": "RockGarden Tufa Rock Aquarium Plant", "group_ids": ["fish-decor-plants", "saltwater-plants-decor", "same-day-delivery-fish-products", "buy-online-pick-up-in-store-fish-products"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1254898-center-1", "startDate": 27867997, "UPC_NUMBER": 600740011016, "deactivated": false, "AverageRating": 4.0625, "TotalReviewCount": 16, "parentCatEntryID": 85103, "PTC_OMNI_TAXONOMY": "Decor", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "RockGarden", "parentCatEntryIDAsString": "85103", "PTC_OMNI_PET_TYPE_PRIMARY": "Fish", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |3668993609|5021015    |Hill's Prescription Diet k/d Kidney Care with Chicken Dry Cat Food                  |hill's prescription diet k/d kidney care with chicken dry cat food                  |{"url": "/shop/en/petcostore/product/hills-prescription-diet-kd-kidney-care-chicken-dry-cat-food", "facets": {"Pet": ["Cat"], "form": ["Dry"], "Flavor": ["Chicken"], "Organic": ["No"], "Features": ["Personalized"], "Holistic": ["No"], "Food Form": ["Dry"], "Lifestage": ["Adult"], "Formula Name": ["K/D"], "How to get it": ["One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Hill's Prescription Diet"], "Health Feature": ["Scientific Formula"], "Primary Flavor": ["Chicken"], "Customer Rating": [4.2967], "Killed Item flag": ["No"], "Primary Pet Type": ["Cat"], "Rx Food Indicator": ["Yes"], "Dietary Preference": ["With Grain"], "Personalized Item flag": ["Yes"], "Prescription Medication": ["No"], "Limited Ingredients Diet": ["No"]}, "mfName": "Hill's Prescription Diet", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2195032-center-1", "itemurl": "/shop/en/petcostore/product/hills-prescription-diet-kd-kidney-care-chicken-dry-cat-food", "itemname": "Hill's Prescription Diet k/d Kidney Care with Chicken Dry Cat Food", "group_ids": ["prescription-cat-food-and-treats", "repeat-delivery-eligible-products", "responsible-manufacturing-cat-food-treats", "sustainable-cat-food-and-treats", "cat-food-with-grain", "cat-repeat-delivery-products", "dry-cat-food"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2195032-center-1", "UPC_NUMBER": 52742725208, "deactivated": false, "AverageRating": 4.2967, "TotalReviewCount": 391, "parentCatEntryID": 1084018, "PTC_OMNI_TAXONOMY": "Consumables|Food|Household Pet", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_RX_FOOD_IND": "Yes", "PTC_OMNI_LIVE_FOOD_FL": "No", "PTC_OMNI_BRAND_PRIMARY": "Hill's Prescription Diet", "PTC_OMNI_FLAVOR_PRIMARY": "Chicken", "parentCatEntryIDAsString": "1084018", "PTC_OMNI_PET_TYPE_PRIMARY": "Cat", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "Yes", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No", "PTC_OMNI_PDP_BEHAVIOR_TEMPLATE": "Rx Food PDP"}|
# |3668992914|5017735    |Pets First Tampa Bay Buccaneers NFL Dog Collar                                      |pets first tampa bay buccaneers nfl dog collar                                      |{"url": "/shop/en/petcostore/product/pets-first-team-petco-tampa-bay-buccaneers-collar", "facets": {"Sport": ["Football"], "Breed Sizes": ["Small"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["Pets First"], "Primary Color": ["Multi-Color"], "Customer Rating": [4.3333], "Killed Item flag": ["No"], "Primary Pet Type": ["Dog"], "Personalized Item flag": ["No"]}, "mfName": "Pets First", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2655174-center-1", "itemurl": "/shop/en/petcostore/product/pets-first-team-petco-tampa-bay-buccaneers-collar", "itemname": "Pets First Tampa Bay Buccaneers NFL Dog Collar", "group_ids": ["nfl-pet-gear", "buy-online-pick-up-in-store-dog-products", "same-day-delivery-dog-products", "dog-collars"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2655174-center-1", "startDate": 26297760, "UPC_NUMBER": 849790039711, "deactivated": false, "AverageRating": 4.3333, "TotalReviewCount": 6, "parentCatEntryID": 826533, "PTC_OMNI_TAXONOMY": "Apparel|Collars|Standard Collars", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Pets First", "parentCatEntryIDAsString": "826533", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |3668993753|5021050    |Majestic Pet Villa Vintage Canopy Bed                                               |majestic pet villa vintage canopy bed                                               |{"url": "/shop/en/petcostore/product/majestic-pet-villa-vintage-canopy-bed-5021050--1", "facets": {"Bed Fill": ["Fiberfill"], "Material": ["Velvet"], "Bed Shape": ["Round"], "How to get it": ["One Time Delivery"], "Primary Brand": ["Majestic Pet"], "Primary Color": ["Grey"], "Customer Rating": [3.5], "Killed Item flag": ["No"], "Primary Pet Type": ["Cat"], "Personalized Item flag": ["No"]}, "mfName": "Majestic Pet", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2708491-center-1", "itemurl": "/shop/en/petcostore/product/majestic-pet-villa-vintage-canopy-bed-5021050--1", "itemname": "Majestic Pet Villa Vintage Canopy Bed", "group_ids": ["cat-bolster-beds", "cat-cave-beds-hideaways"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2708491-center-1", "startDate": 27909786, "UPC_NUMBER": 788995641407, "deactivated": false, "AverageRating": 3.5, "TotalReviewCount": 2, "parentCatEntryID": 1099503, "PTC_OMNI_TAXONOMY": "Beds & Bedding|Beds|Standard Beds", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_PROP_65_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Majestic Pet", "parentCatEntryIDAsString": "1099503", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |3668991152|5001342    |Blue Buffalo Blue Freedom Grain-Free Indoor Fish Recipe Wet Cat Food                |blue buffalo blue freedom grain-free indoor fish recipe wet cat food                |{"url": "/shop/en/petcostore/product/blue-buffalo-freedom-fish-grain-free-indoor-adult-canned-cat-food", "facets": {"Pet": ["Cat"], "Line": ["Blue Freedom"], "Flavor": ["Fish"], "Organic": ["No"], "Holistic": ["Yes"], "Food Form": ["Wet"], "Lifestage": ["Adult"], "How to get it": ["One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Blue Buffalo"], "Health Feature": ["Grain-Free"], "Primary Flavor": ["Seafood"], "Customer Rating": [4.4444], "Killed Item flag": ["No"], "Primary Pet Type": ["Cat"], "Dietary Preference": ["Holistic", "Grain-Free"], "Personalized Item flag": ["No"], "PTC_OMNI_BRAND_SUB_BRND": ["Blue Freedom"], "Limited Ingredients Diet": ["No"]}, "mfName": "Blue Buffalo", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2263576-center-1", "itemurl": "/shop/en/petcostore/product/blue-buffalo-freedom-fish-grain-free-indoor-adult-canned-cat-food", "itemname": "Blue Buffalo Blue Freedom Grain-Free Indoor Fish Recipe Wet Cat Food", "group_ids": ["cat-food-deals", "cat-repeat-delivery-products", "canned-cat-food"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2263576-center-1", "startDate": 27917546, "UPC_NUMBER": 840243101740, "deactivated": false, "AverageRating": 4.4444, "TotalReviewCount": 45, "parentCatEntryID": 208505, "PTC_OMNI_TAXONOMY": "Consumables|Food", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Blue Buffalo", "PTC_OMNI_FLAVOR_PRIMARY": "Seafood", "parentCatEntryIDAsString": "208505", "PTC_OMNI_PET_TYPE_PRIMARY": "Cat", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                                                                                                                                                           |
# |3668987365|103769     |Espree Natural Kitten Shampoo                                                       |espree natural kitten shampoo                                                       |{"url": "/shop/en/petcostore/product/espree-natural-kitten-shampoo", "facets": {"Pet": ["Cat"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery"], "Primary Brand": ["Espree"], "Customer Rating": [4.7333], "Killed Item flag": ["No"], "Primary Pet Type": ["Cat"], "Personalized Item flag": ["No"]}, "mfName": "Espree", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1084364-center-1", "itemurl": "/shop/en/petcostore/product/espree-natural-kitten-shampoo", "itemname": "Espree Natural Kitten Shampoo", "group_ids": ["same-day-delivery-cat-products", "buy-online-pick-up-in-store-cat-products", "repeat-delivery-eligible-products", "sustainable-cat-supplies", "clean-grooming-shampoos-and-conditioners", "cat-shampoo-and-conditioners", "animal-welfare-cat-supplies"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1084364-center-1", "startDate": 26297760, "UPC_NUMBER": 748406004078, "deactivated": false, "AverageRating": 4.7333, "TotalReviewCount": 45, "parentCatEntryID": 15419, "PTC_OMNI_TAXONOMY": "Chemicals|Cleaning & Deodorizing Chemicals|Liquids", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_BRAND_PRIMARY": "Espree", "parentCatEntryIDAsString": "15419", "PTC_OMNI_PET_TYPE_PRIMARY": "Cat", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "No", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |3668988831|5003014    |Soulistic Originals Double Happiness Tuna & Crab Surimi Dinner in Gelee Wet Cat Food|soulistic originals double happiness tuna & crab surimi dinner in gelee wet cat food|{"url": "/shop/en/petcostore/product/soulistic-double-happiness-tuna-and-crab-surimi-dinner-adult-canned-cat-food-in-gelee", "facets": {"Pet": ["Cat"], "Line": ["Originals"], "Flavor": ["Fish"], "Organic": ["No"], "Holistic": ["No"], "Food Form": ["Flakes"], "Lifestage": ["Adult"], "How to get it": ["One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Soulistic"], "Health Feature": ["Weight Management", "Grain-Free"], "Primary Flavor": ["Fish"], "Customer Rating": [4.5846], "Killed Item flag": ["No"], "Primary Pet Type": ["Cat"], "Rx Food Indicator": ["No"], "Dietary Preference": ["Sensitive Stomach", "Limited Ingredient Diet", "Grain-Free"], "Personalized Item flag": ["No"], "PTC_OMNI_BRAND_SUB_BRND": ["Originals"], "Limited Ingredients Diet": ["Yes"]}, "mfName": "Soulistic", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1229184-center-1", "itemurl": "/shop/en/petcostore/product/soulistic-double-happiness-tuna-and-crab-surimi-dinner-adult-canned-cat-food-in-gelee", "itemname": "Soulistic Originals Double Happiness Tuna & Crab Surimi Dinner in Gelee Wet Cat Food", "group_ids": ["grain-free-cat-food", "lid-cat-food-shop", "repeat-delivery-eligible-products", "cat-food-deals", "cat-repeat-delivery-products", "sustainable-cat-food-and-treats", "canned-cat-food", "weuva-deals"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1229184-center-1", "startDate": 26165220, "UPC_NUMBER": 813778012027, "deactivated": false, "AverageRating": 4.5846, "TotalReviewCount": 65, "parentCatEntryID": 71701, "PTC_OMNI_TAXONOMY": "Consumables|Food", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_RX_FOOD_IND": "No", "PTC_OMNI_LIVE_FOOD_FL": "No", "PTC_OMNI_BRAND_PRIMARY": "Soulistic", "PTC_OMNI_FLAVOR_PRIMARY": "Fish", "parentCatEntryIDAsString": "71701", "PTC_OMNI_PET_TYPE_PRIMARY": "Cat", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                 |
# |3668995383|5026292    |Good Lovin' Hickory Smoked Rib Bone Dog Chew                                        |good lovin' hickory smoked rib bone dog chew                                        |{"url": "/shop/en/petcostore/product/good-lovin-hickory-smoked-rib-bone-dog-chew", "facets": {"form": ["Long lasting chew"], "Flavor": ["Beef"], "Food Form": ["Long lasting chew"], "Lifestage": ["All Lifestages"], "How to get it": ["Same Day Delivery", "Free Pickup Today", "One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Good Lovin'"], "Health Feature": ["Grain-Free"], "Customer Rating": [4.2783], "Killed Item flag": ["No"], "Primary Pet Type": ["Dog"], "Rx Food Indicator": ["No"], "Dietary Preference": ["Grain-Free"], "Personalized Item flag": ["No"], "Prescription Medication": ["No"], "Limited Ingredients Diet": ["No"]}, "mfName": "Good Lovin'", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/3691329-center-1", "itemurl": "/shop/en/petcostore/product/good-lovin-hickory-smoked-rib-bone-dog-chew", "itemname": "Good Lovin' Hickory Smoked Rib Bone Dog Chew", "group_ids": ["same-day-delivery-dog-products", "dog-natural-chews-bones", "repeat-delivery-add-on-dog", "repeat-delivery-eligible-products", "dog-repeat-delivery-products", "buy-online-pick-up-in-store-dog-products", "dog-bone-treats"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/3691329-center-1", "startDate": 27802560, "UPC_NUMBER": 800443618899, "deactivated": false, "AverageRating": 4.2783, "TotalReviewCount": 212, "parentCatEntryID": 1598537, "PTC_OMNI_TAXONOMY": "Consumables|Chews", "PTC_OMNI_BOPUS_FLAG": "Yes", "PTC_OMNI_RX_FOOD_IND": "No", "PTC_OMNI_LIVE_FOOD_FL": "No", "PTC_OMNI_PROP_65_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Good Lovin'", "parentCatEntryIDAsString": "1598537", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "Yes", "PTC_OMNI_PDP_BEHAVIOR_TEMPLATE": "Standard PDP"}                                                                                                                                                                                                        |
# |3668995707|5027536    |Nylabone Teethe 'N Tug Puppy Chew Toy                                               |nylabone teethe 'n tug puppy chew toy                                               |{"url": "/shop/en/petcostore/product/nylabone-teethe-n-tug-puppy-chew-toy", "facets": {"Lifestage": ["Puppy"], "How to get it": ["One Time Delivery", "Repeat Delivery"], "Primary Brand": ["Nylabone"], "Primary Color": ["Blue"], "Customer Rating": [4.5], "Killed Item flag": ["No"], "Primary Pet Type": ["Dog"], "Personalized Item flag": ["No"], "Prescription Medication": ["No"]}, "mfName": "Nylabone", "itemimg": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2789025-center-1", "itemurl": "/shop/en/petcostore/product/nylabone-teethe-n-tug-puppy-chew-toy", "itemname": "Nylabone Teethe 'N Tug Puppy Chew Toy", "group_ids": ["puppy-dog-toys", "dog-repeat-delivery-products", "dog-rope-and-tug-toys"], "image_url": "https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/2789025-center-1", "UPC_NUMBER": 18214837428, "deactivated": false, "AverageRating": 4.5, "TotalReviewCount": 18, "parentCatEntryID": 1646509, "PTC_OMNI_TAXONOMY": "Toys", "PTC_OMNI_BOPUS_FLAG": "No", "PTC_OMNI_PROP_65_FLAG": "No", "PTC_OMNI_BRAND_PRIMARY": "Nylabone", "parentCatEntryIDAsString": "1646509", "PTC_OMNI_PRIMARY_ITEM_FLAG": "Yes", "PTC_OMNI_IN_STORE_ONLY_FLAG": "No", "PTC_OMNI_REPEAT_DELIVERY_FL": "Yes", "PTC_OMNI_PERSONALIZED_ITEM_FL": "No", "PTC_OMNI_SAME_DAY_DELIVERY_FG": "No"}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# +----------+-----------+------------------------------------------------------------------------------------+------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import from_json, col

# Определим структуру для metadata_json
metadata_schema = StructType([
    StructField("url", StringType(), True),
    StructField("image_url", StringType(), True),
    StructField("facets", StructType([
        StructField("How to get it", ArrayType(StringType()), True),
        StructField("Primary Brand", ArrayType(StringType()), True),
        StructField("Primary Color", ArrayType(StringType()), True),
        StructField("Killed Item flag", ArrayType(StringType()), True),
        StructField("Primary Pet Type", ArrayType(StringType()), True),
        StructField("Personalized Item flag", ArrayType(StringType()), True),
        StructField("Prescription Medication", ArrayType(StringType()), True)
    ]), True),
    StructField("group_ids", ArrayType(StringType()), True),
    StructField("PTC_OMNI_REPEAT_DELIVERY_FL", StringType(), True),
    StructField("parentCatEntryIDAsString", StringType(), True),
    StructField("PTC_OMNI_PRIMARY_ITEM_FLAG", StringType(), True),
    StructField("mfName", StringType(), True),
    StructField("PTC_OMNI_IN_STORE_ONLY_FLAG", StringType(), True),
    StructField("PTC_OMNI_PROP_65_FLAG", StringType(), True),
    StructField("PTC_OMNI_TAXONOMY", StringType(), True),
    StructField("PTC_OMNI_PERSONALIZED_ITEM_FL", StringType(), True),
    StructField("parentCatEntryID", StringType(), True),
    StructField("startDate", StringType(), True),
    StructField("deactivated", BooleanType(), True),
    StructField("PTC_OMNI_SAME_DAY_DELIVERY_FG", StringType(), True),
    StructField("PTC_OMNI_PDP_BEHAVIOR_TEMPLATE", StringType(), True),
    StructField("itemname", StringType(), True),
    StructField("PTC_OMNI_BOPUS_FLAG", StringType(), True),
    StructField("PTC_OMNI_BRAND_PRIMARY", StringType(), True),
    StructField("itemurl", StringType(), True),
    StructField("itemimg", StringType(), True),
    StructField("UPC_NUMBER", StringType(), True)
])

# Преобразуем metadata_json в структуру
data_items_parsed = data_items_filtered.withColumn(
    "metadata_parsed", from_json(col("metadata_json"), metadata_schema)
)

# Извлекаем нужные атрибуты из metadata_parsed в отдельные столбцы
data_items_with_columns = data_items_parsed.select(
    "id", "customer_id", "name", "name_lower",
    "metadata_parsed.url", "metadata_parsed.image_url", "metadata_parsed.itemname",
    "metadata_parsed.facets", "metadata_parsed.group_ids",
    "metadata_parsed.PTC_OMNI_REPEAT_DELIVERY_FL", "metadata_parsed.PTC_OMNI_PRIMARY_ITEM_FLAG",
    "metadata_parsed.PTC_OMNI_TAXONOMY", "metadata_parsed.PTC_OMNI_PERSONALIZED_ITEM_FL",
    "metadata_parsed.PTC_OMNI_SAME_DAY_DELIVERY_FG", "metadata_parsed.PTC_OMNI_PDP_BEHAVIOR_TEMPLATE",
    "metadata_parsed.PTC_OMNI_BOPUS_FLAG", "metadata_parsed.PTC_OMNI_BRAND_PRIMARY",
    "metadata_parsed.itemurl", "metadata_parsed.itemimg", "metadata_parsed.UPC_NUMBER"
)

# Показываем результат
# data_items_with_columns.show(truncate=False)

# %%
# one_item = data_items_with_columns.filter(data_items.customer_id == 5190834)
# one_item.show()

# %%
# one_item.select('facets').collect()

# %%
same_columns = ['name', 'name_lower', 'url', 'image_url', 'itemname', 'facets']

# %%
from pyspark.sql.functions import collect_list, udf
from pyspark.sql.types import ArrayType, StringType

# Функция для вычисления пересечения списка списков
def array_intersection(arrays):
    if not arrays:
        return []
    # Инициализируем пересечение первым списком
    result = set(arrays[0])
    # Пересекаем с каждым следующим списком
    for arr in arrays[1:]:
        result = result.intersection(arr)
    return list(result)

# Регистрируем UDF для вычисления пересечения
intersection_udf = udf(array_intersection, ArrayType(StringType()))

# Группируем по customer_id и собираем все group_ids в список списков, затем вычисляем пересечение
data_items_intersect = data_items_with_columns.groupBy("customer_id") \
    .agg(collect_list("group_ids").alias("group_ids_list")) \
    .withColumn("group_ids_intersect", intersection_udf("group_ids_list"))

# Выводим результат
# data_items_intersect.select("customer_id", "group_ids_intersect").show(truncate=False)

# %%
data_items_intersect.filter(data_items.customer_id == 5190834).select('group_ids_intersect').collect()[0]
# Out:
# Row(group_ids_intersect=['same-day-delivery-cat-products', 'buy-online-pick-up-in-store-dog-products', 'buy-online-pick-up-in-store-cat-products', 'same-day-delivery-dog-products', 'cat-feeding-scoops', 'dog-food-containers', 'dog-bowls'])

# %%
from pyspark.sql.functions import first

# Предполагаем, что same_columns уже определён, например:
# same_columns = ["customer_id", "url", "image_url", "itemname", ...]

# Агрегируем data_items_with_columns по customer_id:
# Для каждого столбца из same_columns (кроме customer_id) берем первое значение
aggregated_same = data_items_with_columns.groupBy("customer_id").agg(
    *[first(col_name).alias(col_name) for col_name in same_columns if col_name != "customer_id"]
)

# Теперь объединяем агрегированный DataFrame с DataFrame, содержащим group_ids_intersect.
# Предполагается, что data_items_intersect был получен ранее, например:
# data_items_intersect = data_items_with_columns.groupBy("customer_id") \
#     .agg(collect_list("group_ids").alias("group_ids_list")) \
#     .withColumn("group_ids_intersect", intersection_udf("group_ids_list"))
final_df = aggregated_same.join(
    data_items_intersect.select("customer_id", "group_ids_intersect"),
    on="customer_id",
    how="left"
)

# %%
from pyspark.sql.functions import col

final_df = final_df.withColumn("How_to_get_it", col("facets.`How to get it`")) \
                   .withColumn("Primary_Brand", col("facets.`Primary Brand`")) \
                   .withColumn("Primary_Color", col("facets.`Primary Color`")) \
                   .withColumn("Killed_Item_flag", col("facets.`Killed Item flag`")) \
                   .withColumn("Primary_Pet_Type", col("facets.`Primary Pet Type`")) \
                   .withColumn("Personalized_Item_flag", col("facets.`Personalized Item flag`")) \
                   .withColumn("Prescription_Medication", col("facets.`Prescription Medication`"))

# Если исходный столбец facets больше не нужен, можно его удалить:
final_df = final_df.drop("facets")

final_df.show(truncate=False)
# Out:
# +-----------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------+-------------+----------------+----------------+----------------------+-----------------------+
# |customer_id|name                                                                           |name_lower                                                                     |url                                                                                  |image_url                                                                                 |itemname                                                                       |group_ids_intersect                                                                                                                                                                                                                                                                                                            |How_to_get_it                                                             |Primary_Brand          |Primary_Color|Killed_Item_flag|Primary_Pet_Type|Personalized_Item_flag|Prescription_Medication|
# +-----------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------+-------------+----------------+----------------+----------------------+-----------------------+
# |100039     |Prevue Pet Products Cockatiel Court Tabletop Playpen                           |prevue pet products cockatiel court tabletop playpen                           |/shop/en/petcostore/product/prevue-pet-cockatiel-court-tabletop-playpen              |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/189367-center-1  |Prevue Pet Products Cockatiel Court Tabletop Playpen                           |[cockatiel-perches, parakeet-perches, conure-perches, finch-perches, bird-perches-swings-and-playstands]                                                                                                                                                                                                                       |[One Time Delivery]                                                       |[Prevue Pet Products]  |[Multi-Color]|[No]            |[Bird]          |[No]                  |NULL                   |
# |100140     |Nature's Miracle Orange Scent Oxy Formula Set-In Stain Destroyer for Dog Messes|nature's miracle orange scent oxy formula set-in stain destroyer for dog messes|/shop/en/petcostore/product/natures-miracle-orange-oxy-power-stain-and-odor-remover  |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/379085-center-1  |Nature's Miracle Orange Scent Oxy Formula Set-In Stain Destroyer for Dog Messes|[stain-and-odor-removers, same-day-delivery-cat-products, dog-repeat-delivery-products, buy-online-pick-up-in-store-dog-products, dog-odor-removal-and-cleaners, buy-online-pick-up-in-store-cat-products, repeat-delivery-eligible-products, same-day-delivery-dog-products, dog-potty-training, pet-hair-vacuums-accessories]|[Same Day Delivery, Free Pickup Today, One Time Delivery, Repeat Delivery]|[Nature's Miracle]     |NULL         |[No]            |[Cat,Dog]       |[No]                  |NULL                   |
# |100243     |Kaytee Forti-Diet Pro Health Honey Stick Cockatiel Treats                      |kaytee forti-diet pro health honey stick cockatiel treats                      |/shop/en/petcostore/product/kaytee-forti-diet-pro-health-honey-stick-cockatiel-treats|https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/648400-right-1   |Kaytee Forti-Diet Pro Health Honey Stick Cockatiel Treats                      |[conure-treats, repeat-delivery-eligible-products, bird-treats-sticks-grit, amazon-parrot-treats, buy-online-pick-up-in-store-bird-products, cockatiel-treats, same-day-delivery-bird-products, bird-repeat-delivery-products, repeat-delivery-add-on-bird]                                                                    |[Same Day Delivery, Free Pickup Today, One Time Delivery, Repeat Delivery]|[Kaytee]               |NULL         |[No]            |[Bird]          |[No]                  |NULL                   |
# |100244     |Kaytee Forti-Diet Pro Health Honey Stick Parrot Treats                         |kaytee forti-diet pro health honey stick parrot treats                         |/shop/en/petcostore/product/kaytee-forti-diet-pro-health-honey-stick-parrot-treats   |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/648418-right-1   |Kaytee Forti-Diet Pro Health Honey Stick Parrot Treats                         |[repeat-delivery-eligible-products, bird-treats-sticks-grit, amazon-parrot-treats, buy-online-pick-up-in-store-bird-products, same-day-delivery-bird-products, bird-repeat-delivery-products]                                                                                                                                  |[Same Day Delivery, Free Pickup Today, One Time Delivery, Repeat Delivery]|[Kaytee]               |NULL         |[No]            |[Bird]          |[No]                  |NULL                   |
# |100254     |Royal Canin Shih Tzu Adult Breed Specific Dry Dog Food                         |royal canin shih tzu adult breed specific dry dog food                         |/shop/en/petcostore/product/royal-canin-mini-canine-health-nutrition-shih-tzu        |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1463616-center-1 |Royal Canin Shih Tzu Adult Breed Specific Dry Dog Food                         |[small-breed-dog-food, repeat-delivery-eligible-products, buy-online-pick-up-in-store-dog-products, dog-repeat-delivery-products, dry-dog-food, dry-dog-food-with-grain]                                                                                                                                                       |[Same Day Delivery, Free Pickup Today, One Time Delivery, Repeat Delivery]|[Royal Canin]          |NULL         |[No]            |[Dog]           |[No]                  |NULL                   |
# |100491     |KONG Zoom Groom Brush                                                          |kong zoom groom brush                                                          |/shop/en/petcostore/product/kong-zoom-groom-brush                                    |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/823929-center-1  |KONG Zoom Groom Brush                                                          |[buy-online-pick-up-in-store-dog-products, dog-brushes, same-day-delivery-dog-products]                                                                                                                                                                                                                                        |[Same Day Delivery, Free Pickup Today, One Time Delivery]                 |[KONG]                 |[Blue]       |[No]            |[Dog]           |[No]                  |NULL                   |
# |100507     |TetraPond AquaSafe Pond Water Conditioner                                      |tetrapond aquasafe pond water conditioner                                      |/shop/en/petcostore/product/tetrapond-aquasafe-pond-water-conditioner                |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1306340-Center-1 |TetraPond AquaSafe Pond Water Conditioner                                      |[pond-water-care, pond-supplies, repeat-delivery-eligible-products, fish-repeat-delivery-products, fish-tank-water-conditioners-additives]                                                                                                                                                                                     |[One Time Delivery, Repeat Delivery]                                      |[Tetra]                |NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |100568     |PetSafe 3 Volt Lithium Battery Module                                          |petsafe 3 volt lithium battery module                                          |/shop/en/petcostore/product/petsafe-3-volt-lithium-battery-module                    |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1003364-center-1 |PetSafe 3 Volt Lithium Battery Module                                          |[electronic-dog-training-collars-and-accessories]                                                                                                                                                                                                                                                                              |[Same Day Delivery, Free Pickup Today, One Time Delivery]                 |[PetSafe]              |NULL         |[Yes]           |[Dog]           |[No]                  |NULL                   |
# |100767     |Coastal Pet 3/4" Personalized Nylon Leash in Purple                            |coastal pet 3/4" personalized nylon leash in purple                            |/shop/en/petcostore/product/coastal-pet-34-personalized-nylon-lead-in-purple         |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1015176-center-1 |Coastal Pet 3/4" Personalized Nylon Leash in Purple                            |[personalized-leashes, dog-leashes]                                                                                                                                                                                                                                                                                            |[One Time Delivery]                                                       |[Coastal Pet]          |[Purple]     |[No]            |[Dog]           |[Yes]                 |NULL                   |
# |100768     |Coastal Pet 3/4" Personalized Nylon Leash in Red                               |coastal pet 3/4" personalized nylon leash in red                               |/shop/en/petcostore/product/coastal-pet-34-personalized-nylon-lead-in-red            |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1015184-center-1 |Coastal Pet 3/4" Personalized Nylon Leash in Red                               |[personalized-leashes, dog-leashes]                                                                                                                                                                                                                                                                                            |[One Time Delivery]                                                       |[Coastal Pet]          |[Red]        |[No]            |[Dog]           |[Yes]                 |NULL                   |
# |101051     |PondCare MelaFix                                                               |pondcare melafix                                                               |/shop/en/petcostore/product/pondcare-melafix                                         |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/727814-center-1  |PondCare MelaFix                                                               |[pond-supplies, repeat-delivery-eligible-products, fish-health-wellness, same-day-delivery-fish-products, buy-online-pick-up-in-store-fish-products]                                                                                                                                                                           |[Same Day Delivery, Free Pickup Today, One Time Delivery]                 |[API]                  |NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101065     |Assorted Platies                                                               |assorted platies                                                               |/shop/en/petcostore/product/assorted-platies                                         |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1032194-center-1 |Assorted Platies                                                               |[community-schooling-freshwater-fish, freshwater-fish-platies]                                                                                                                                                                                                                                                                 |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101068     |Male Betta                                                                     |male betta                                                                     |/shop/en/petcostore/product/male-veiltail-betta                                      |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1031759-Center-1 |Male Betta                                                                     |[freshwater-fish, freshwater-fish-bettas, betta-fish-shop, live-betta-fish]                                                                                                                                                                                                                                                    |[One Time Delivery]                                                       |[Imagitarium]          |NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101076     |Grade A Butterfly Koi                                                          |grade a butterfly koi                                                          |/shop/en/petcostore/product/grade-a-butterfly-koi                                    |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1032135-center-1 |Grade A Butterfly Koi                                                          |[live-pond-fish, pond-fish-koi-fish, freshwater-fish, freshwater-fish-goldfish]                                                                                                                                                                                                                                                |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101077     |Fancy Male Guppy                                                               |fancy male guppy                                                               |/shop/en/petcostore/product/assorted-male-fancy-guppies                              |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1032070-center-11|Fancy Male Guppy                                                               |[community-schooling-freshwater-fish, freshwater-fish-guppies]                                                                                                                                                                                                                                                                 |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101078     |Calico Ryukin Goldfish                                                         |calico ryukin goldfish                                                         |/shop/en/petcostore/product/calico-ryukin-goldfish                                   |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/3590528-center-1 |Calico Ryukin Goldfish                                                         |[freshwater-fish, live-pond-fish, freshwater-fish-goldfish]                                                                                                                                                                                                                                                                    |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101088     |Jack Dempsey Cichlid                                                           |jack dempsey cichlid                                                           |/shop/en/petcostore/product/jack-dempsey-cichlid                                     |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1031899-right-1  |Jack Dempsey Cichlid                                                           |[freshwater-fish, freshwater-cichlids]                                                                                                                                                                                                                                                                                         |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101090     |Grade A Koi                                                                    |grade a koi                                                                    |/shop/en/petcostore/product/grade-a-koi                                              |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1053523-right-1  |Grade A Koi                                                                    |[live-pond-fish, pond-fish-koi-fish, freshwater-fish, freshwater-fish-goldfish]                                                                                                                                                                                                                                                |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |[No]                   |
# |101098     |Rainbow Shark                                                                  |rainbow shark                                                                  |/shop/en/petcostore/product/rainbow-shark                                            |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/1032275-Center-5 |Rainbow Shark                                                                  |[freshwater-fish, freshwater-bottom-dwellers, freshwater-fish-sharks]                                                                                                                                                                                                                                                          |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# |101100     |Red Cap Oranda Goldfish                                                        |red cap oranda goldfish                                                        |/shop/en/petcostore/product/red-cap-oranda-goldfish                                  |https://assets.petco.com/petco/image/upload/f_auto,q_auto,w_190/dpr_auto/3590501-center-1 |Red Cap Oranda Goldfish                                                        |[live-pond-fish, freshwater-fish, freshwater-fish-goldfish]                                                                                                                                                                                                                                                                    |[One Time Delivery]                                                       |[Petco Freshwater Fish]|NULL         |[No]            |[Fish]          |[No]                  |NULL                   |
# +-----------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------+-----------------------+-------------+----------------+----------------+----------------------+-----------------------+
# only showing top 20 rows

# %%
# Переводим PySpark DataFrame в Pandas
pandas_final_df = final_df.toPandas()

# Указываем путь для сохранения CSV
output_csv_path = '/content/drive/My Drive/Colab Notebooks/diploma/results/processed_data/items.csv'

# Сохраняем Pandas DataFrame в CSV
pandas_final_df.to_csv(output_csv_path, index=False)

print(f"Датасет сохранён в формате CSV по пути {output_csv_path}.")
# Out:
# Датасет сохранён в формате CSV по пути /content/drive/My Drive/Colab Notebooks/diploma/results/processed_data/items.csv.

# %%
import pandas as pd
pd.read_csv(output_csv_path)
# Out:
#        customer_id                                               name  \
# 0           100039  Prevue Pet Products Cockatiel Court Tabletop P...
# 1           100140  Nature's Miracle Orange Scent Oxy Formula Set-...
# 2           100243  Kaytee Forti-Diet Pro Health Honey Stick Cocka...
# 3           100244  Kaytee Forti-Diet Pro Health Honey Stick Parro...
# 4           100254  Royal Canin Shih Tzu Adult Breed Specific Dry ...
# ...            ...                                                ...
# 31996         8830               PoochPads Reusable Housebreaking Pad
# 31997         8864                                   PetSafe Cat Flap
# 31998         9095  TropiClean Papaya Mist Deodorizing Spray for Pets
# 31999         9612                             Zoo Med Little Dripper
# 32000         9655              Vitakraft Mini-Pop Small Animal Treat
#
#                                               name_lower  \
# 0      prevue pet products cockatiel court tabletop p...
# 1      nature's miracle orange scent oxy formula set-...
# 2      kaytee forti-diet pro health honey stick cocka...
# 3      kaytee forti-diet pro health honey stick parro...
# 4      royal canin shih tzu adult breed specific dry ...
# ...                                                  ...
# 31996               poochpads reusable housebreaking pad
# 31997                                   petsafe cat flap
# 31998  tropiclean papaya mist deodorizing spray for pets
# 31999                             zoo med little dripper
# 32000              vitakraft mini-pop small animal treat
#
#                                                      url  \
# 0      /shop/en/petcostore/product/prevue-pet-cockati...
# 1      /shop/en/petcostore/product/natures-miracle-or...
# 2      /shop/en/petcostore/product/kaytee-forti-diet-...
# 3      /shop/en/petcostore/product/kaytee-forti-diet-...
# 4      /shop/en/petcostore/product/royal-canin-mini-c...
# ...                                                  ...
# 31996  /shop/en/petcostore/product/poochpads-reusable...
# 31997       /shop/en/petcostore/product/petsafe-cat-flap
# 31998  /shop/en/petcostore/product/tropiclean-natural...
# 31999  /shop/en/petcostore/product/zoo-med-little-dri...
# 32000  /shop/en/petcostore/product/vitakraft-mini-pop...
#
#                                                image_url  \
# 0      https://assets.petco.com/petco/image/upload/f_...
# 1      https://assets.petco.com/petco/image/upload/f_...
# 2      https://assets.petco.com/petco/image/upload/f_...
# 3      https://assets.petco.com/petco/image/upload/f_...
# 4      https://assets.petco.com/petco/image/upload/f_...
# ...                                                  ...
# 31996  https://assets.petco.com/petco/image/upload/f_...
# 31997  https://assets.petco.com/petco/image/upload/f_...
# 31998  https://assets.petco.com/petco/image/upload/f_...
# 31999  https://assets.petco.com/petco/image/upload/f_...
# 32000  https://assets.petco.com/petco/image/upload/f_...
#
#                                                 itemname  \
# 0      Prevue Pet Products Cockatiel Court Tabletop P...
# 1      Nature's Miracle Orange Scent Oxy Formula Set-...
# 2      Kaytee Forti-Diet Pro Health Honey Stick Cocka...
# 3      Kaytee Forti-Diet Pro Health Honey Stick Parro...
# 4      Royal Canin Shih Tzu Adult Breed Specific Dry ...
# ...                                                  ...
# 31996               PoochPads Reusable Housebreaking Pad
# 31997                                   PetSafe Cat Flap
# 31998  TropiClean Papaya Mist Deodorizing Spray for Pets
# 31999                             Zoo Med Little Dripper
# 32000              Vitakraft Mini-Pop Small Animal Treat
#
#                                      group_ids_intersect  \
# 0      ['cockatiel-perches', 'parakeet-perches', 'con...
# 1      ['stain-and-odor-removers', 'same-day-delivery...
# 2      ['conure-treats', 'repeat-delivery-eligible-pr...
# 3      ['repeat-delivery-eligible-products', 'bird-tr...
# 4      ['small-breed-dog-food', 'repeat-delivery-elig...
# ...                                                  ...
# 31996  ['dog-potty-training', 'dog-repeat-delivery-pr...
# 31997                            ['cat-doors-and-flaps']
# 31998  ['animal-welfare-dog-supplies', 'sustainable-d...
# 31999  ['buy-online-pick-up-in-store-reptile-products...
# 32000  ['chinchilla-food-hay', 'buy-online-pick-up-in...
#
#                                            How_to_get_it  \
# 0                                  ['One Time Delivery']
# 1      ['Same Day Delivery', 'Free Pickup Today', 'On...
# 2      ['Same Day Delivery', 'Free Pickup Today', 'On...
# 3      ['Same Day Delivery', 'Free Pickup Today', 'On...
# 4      ['Same Day Delivery', 'Free Pickup Today', 'On...
# ...                                                  ...
# 31996           ['One Time Delivery', 'Repeat Delivery']
# 31997                              ['One Time Delivery']
# 31998  ['Same Day Delivery', 'Free Pickup Today', 'On...
# 31999  ['Same Day Delivery', 'Free Pickup Today', 'On...
# 32000  ['Same Day Delivery', 'Free Pickup Today', 'On...
#
#                  Primary_Brand    Primary_Color Killed_Item_flag  \
# 0      ['Prevue Pet Products']  ['Multi-Color']           ['No']
# 1         ["Nature's Miracle"]              NaN           ['No']
# 2                   ['Kaytee']              NaN           ['No']
# 3                   ['Kaytee']              NaN           ['No']
# 4              ['Royal Canin']              NaN           ['No']
# ...                        ...              ...              ...
# 31996            ['PoochPads']              NaN           ['No']
# 31997              ['PetSafe']        ['White']           ['No']
# 31998           ['TropiClean']              NaN           ['No']
# 31999              ['Zoo Med']              NaN           ['No']
# 32000            ['Vitakraft']              NaN           ['No']
#
#        Primary_Pet_Type Personalized_Item_flag Prescription_Medication
# 0              ['Bird']                 ['No']                     NaN
# 1           ['Cat,Dog']                 ['No']                     NaN
# 2              ['Bird']                 ['No']                     NaN
# 3              ['Bird']                 ['No']                     NaN
# 4               ['Dog']                 ['No']                     NaN
# ...                 ...                    ...                     ...
# 31996           ['Dog']                 ['No']                     NaN
# 31997           ['Cat']                 ['No']                  ['No']
# 31998           ['Dog']                 ['No']                     NaN
# 31999       ['Reptile']                 ['No']                     NaN
# 32000  ['Small Animal']                 ['No']                     NaN
#
# [32001 rows x 14 columns]
